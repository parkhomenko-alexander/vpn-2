# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn import preprocessing
from nfstream import NFStreamer

# %%
df = NFStreamer('data/all_3.pcapng').to_pandas()
X = df[["bidirectional_packets", "bidirectional_bytes"]]
Y = df["application_name"].apply(lambda x: {'WireGuard': 1, 'OpenVPN': 2}.get(x, 0))


X_train, X_test, Y_train, Y_test = train_test_split(X, Y,  
                                                    test_size=0.2, 
                                                    random_state=49)

# %%
model = RandomForestClassifier()
model.fit(X_train, Y_train)
print('Train: ', model.score(X_train, Y_train))
print('Test : ', model.score(X_test, Y_test))
# Out:
# Train:  1.0
# Test :  0.9952380952380953

# %%
df1 = NFStreamer('data/open.pcapng').to_pandas()
Xn = df1[["bidirectional_packets", "bidirectional_bytes"]]
Yn = model.predict(Xn)

# %%
Xn.head(100)
# Out:
#     bidirectional_packets  bidirectional_bytes
# 0                       2                  126
# 1                      12                 1602
# 2                       6                  390
# 3                       2                  728
# 4                       2                  684
# 5                       2                  156
# 6                      12                13840
# 7                      33                 8978
# 8                       6                 3996
# 9                       1                   75
# 10                      2                  314
# 11                      2                  286
# 12                      7                 4662
# 13                     15                 2389
# 14                      1                   75
# 15                     10                 1634
# 16                      4                  716
# 17                     28                 2512
# 18                     28                 3072
# 19                      1                   60
# 20                     25                 2410
# 21                      2                  172
# 22                      5                 3330
# 23                      6                 4116
# 24                      3                  648
# 25                      1                   95
# 26                      7                 4662
# 27                      7                 4802
# 28                      4                  864
# 29                     27                 2898
# 30                   3613              2388713
# 31                     21                 2148
# 32                      1                   60
# 33                      5                  324
# 34                      1                   60
# 35                      8                 1256
# 36                     22                 1244
# 37                      5                  334
# 38                     12                13456
# 39                      8                 1384
# 40                     12                 1988
# 41                      6                 4116
# 42                      1                   95
# 43                      1                   75
# 44                      7                 4802
# 45                      1                   95
